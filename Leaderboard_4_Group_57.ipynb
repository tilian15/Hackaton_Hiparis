# %% [markdown]
# # Necessary library installations

# %%
# Installation of AutoML SOTA library and dask
# !pip install autogluon
# !pip install dask

# %% [markdown]
# # Some simple Feature Engineering and Data Cleaning

# %%
import numpy as np
import pandas as pd
import os
from autogluon.tabular  import TabularDataset, TabularPredictor


X_train = pd.read_csv('path_to_x_train_file', low_memory=False)
X_test = pd.read_csv('path_to_x_test_file', low_memory=False)

# %%
# Remove columns with a missing rate higher than 50%
missing_rates = X_train.isnull().mean()
columns_to_keep = missing_rates[missing_rates <= 0.5].index

X_train=X_train[columns_to_keep[1:]]
X_test = X_test[columns_to_keep[1:-1]]

# %%
# Convert INSEE columns to float64 data type
insee_columns = X_train.filter(regex='^insee_').columns
X_train[insee_columns] = X_train[insee_columns].apply(pd.to_numeric, errors='coerce')
X_test[insee_columns] = X_test[insee_columns].apply(pd.to_numeric, errors='coerce')
print(X_train[insee_columns].dtypes)
# Out:
# insee_%_agri              float64
# insee_pop_commune         float64
# insee_med_living_level    float64
# insee_%_ind               float64
# insee_%_const             float64
# dtype: object

# %%
non_numeric_cols = X_test.select_dtypes(include=['object', 'category']).columns
time_cols = [col for col in X_train.columns if 'date' in col.lower()]
categorical_cols = [col for col in non_numeric_cols if col not in time_cols]

# %%
# Define some preprocessing functions
def date(df):
    df['piezo_measurement_date'] = pd.to_datetime(df['piezo_measurement_date'])
    df['year'] = df['piezo_measurement_date'].dt.year
    df['month'] = df['piezo_measurement_date'].dt.month
    df['day'] = df['piezo_measurement_date'].dt.day
    df = df.drop(columns=['piezo_measurement_date'])
    return df

def engineer_features(df):

    for window in [7, 14]:
        df[f'temp_avg_{window}d'] = df.groupby('piezo_station_bss_code')['meteo_temperature_avg'] \
            .rolling(window=window, min_periods=1) \
            .mean() \
            .reset_index(0, drop=True)

        df[f'rain_sum_{window}d'] = df.groupby('piezo_station_bss_code')['meteo_rain_height'] \
            .rolling(window=window, min_periods=1) \
            .sum() \
            .reset_index(0, drop=True)
    df['rain_temp_interaction'] = df['meteo_rain_height'] * df['meteo_temperature_avg']
    return df

# %%
columns_to_drop = ['piezo_station_update_date', 'meteo_date', 'hydro_observation_date_elab']
X_train = X_train.drop(columns=columns_to_drop)
X_test = X_test.drop(columns=columns_to_drop)

# DateTime preprocessing
X_train=date(X_train)
X_test=date(X_test)

# Preliminary Feature Engineering
X_train=engineer_features(X_train)
X_test=engineer_features(X_test)

# %%
non_numeric_cols = X_test.select_dtypes(include=['object', 'category']).columns
numeric_cols=X_train.select_dtypes(include=['number']).columns
time_cols = [col for col in X_train.columns if 'date' in col.lower()]
categorical_cols = [col for col in non_numeric_cols if col not in time_cols]

# %%
for col in numeric_cols:
    X_train[col].fillna(X_train[col].median(), inplace=True)
    X_test[col].fillna(X_test[col].median(), inplace=True)
for col in categorical_cols:
    X_train[col].fillna('nan', inplace=True)
    X_test[col].fillna('nan', inplace=True)
# Out:
# <ipython-input-13-72cbdb4df12e>:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[col].fillna(X_train[col].median(), inplace=True)
# <ipython-input-13-72cbdb4df12e>:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[col].fillna(X_test[col].median(), inplace=True)
# <ipython-input-13-72cbdb4df12e>:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_train[col].fillna('nan', inplace=True)
# <ipython-input-13-72cbdb4df12e>:10: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   X_test[col].fillna('nan', inplace=True)

# %% [markdown]
# # Model Training

# %%
validation_df = X_train.sample(frac=0.2, random_state=42)
train_df = X_train.drop(validation_df.index)

# %%
# Define our stacking ensembly method predictor
predictor = TabularPredictor(
    label='piezo_groundwater_level_category',
    eval_metric='f1_weighted',
    problem_type='multiclass'
)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20241201_100925"

# %%
predictor.fit(
    train_data=train_df,
    presets='best_quality',
    time_limit=3600*3,
    hyperparameters={
        'CAT': {
            'iterations': 100,
            'early_stopping_rounds': 20,
            'learning_rate': 0.1
        },
        'GBM': {
            'n_estimators': 100,
            'early_stopping_rounds': 20,
            'learning_rate': 0.1},
        'XGB':{
            'n_estimators': 100,
            'early_stopping_rounds': 20,
            'learning_rate': 0.1
        },
        'FASTAI': {
        }
    }
)
# Out:
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.2
# Python Version:     3.10.12
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# CPU Count:          12
# Memory Avail:       61.51 GB / 83.48 GB (73.7%)
# Disk Space Avail:   197.66 GB / 235.68 GB (83.9%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 2700s of the 10800s of remaining time (25%).
# 		Context path: "/content/AutogluonModels/ag-20241201_100925/ds_sub_fit/sub_fit_ho"
# (_dystack pid=4621) 	0.7592	 = Validation score   (f1_weighted)
# (_dystack pid=4621) 	758.99s	 = Training   runtime
# (_dystack pid=4621) 	85.58s	 = Validation runtime
# (_dystack pid=4621) Fitting model: CatBoost_BAG_L1 ... Training model for up to 834.01s of the 1656.88s of remaining time.
# (_dystack pid=4621) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.90% memory usage per fold, 63.61%/80.00% total).
# (_dystack pid=4621) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=15.90%)
# (_dystack pid=11442) Running DyStack sub-fit ...
# (_dystack pid=11442) Beginning AutoGluon training ... Time limit = 2700s
# (_dystack pid=11442) AutoGluon will save models to "/content/AutogluonModels/ag-20241201_100925/ds_sub_fit/sub_fit_ho"
# (_dystack pid=11442) Train Data Rows:    2012669
# (_dystack pid=11442) Train Data Columns: 94
# (_dystack pid=11442) Label Column:       piezo_groundwater_level_category
# (_dystack pid=11442) Problem Type:       multiclass
# (_dystack pid=11442) Preprocessing data ...
# (_dystack pid=11442) Train Data Class Count: 5
# (_dystack pid=11442) Using Feature Generators to preprocess the data ...
# (_dystack pid=11442) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=11442) 	Available Memory:                    65583.78 MB
# (_dystack pid=11442) 	Train Data (Original)  Memory Usage: 5418.60 MB (8.3% of available memory)
# (_dystack pid=11442) 	Warning: Data size prior to feature transformation consumes 8.3% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# (_dystack pid=11442) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=11442) 	Stage 1 Generators:
# (_dystack pid=11442) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=11442) 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=11442) 	Stage 2 Generators:
# (_dystack pid=11442) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=11442) 	Stage 3 Generators:
# (_dystack pid=11442) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=11442) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=11442) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=11442) 		Fitting TextSpecialFeatureGenerator...
# (_dystack pid=11442) 			Fitting BinnedFeatureGenerator...
# (_dystack pid=11442) 			Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=11442) 		Fitting TextNgramFeatureGenerator...
# (_dystack pid=11442) 			Fitting CountVectorizer for text features: ['piezo_station_pe_label', 'piezo_producer_name']
# (_dystack pid=11442) 			CountVectorizer fit with vocabulary size = 313
# (_dystack pid=11442) 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# (_dystack pid=11442) 		Reducing Vectorizer vocab size from 313 to 185 to avoid OOM error
# (_dystack pid=11442) 	Stage 4 Generators:
# (_dystack pid=11442) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=11442) 	Stage 5 Generators:
# (_dystack pid=11442) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=11442) 	Useless Original Features (Count: 2): ['hydro_method_code', 'hydro_method_label']
# (_dystack pid=11442) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=11442) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=11442) 		These features do not need to be present at inference time.
# (_dystack pid=11442) 	Unused Original Features (Count: 5): ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name']
# (_dystack pid=11442) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=11442) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=11442) 		These features do not need to be present at inference time.
# (_dystack pid=11442) 		('object', []) : 5 | ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name']
# (_dystack pid=11442) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=11442) 		('float', [])        : 55 | ['piezo_station_investigation_depth', 'piezo_station_altitude', 'piezo_station_longitude', 'piezo_station_latitude', 'piezo_continuity_code', ...]
# (_dystack pid=11442) 		('int', [])          :  7 | ['meteo_id', 'meteo_altitude', 'hydro_status_code', 'hydro_qualification_code', 'year', ...]
# (_dystack pid=11442) 		('object', [])       : 23 | ['piezo_station_department_code', 'piezo_station_commune_code_insee', 'piezo_station_bdlisa_codes', 'piezo_station_bss_code', 'piezo_station_commune_name', ...]
# (_dystack pid=11442) 		('object', ['text']) :  2 | ['piezo_station_pe_label', 'piezo_producer_name']
# (_dystack pid=11442) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=11442) 		('category', [])                    : 22 | ['piezo_station_department_code', 'piezo_station_commune_code_insee', 'piezo_station_bdlisa_codes', 'piezo_station_bss_code', 'piezo_station_commune_name', ...]
# (_dystack pid=11442) 		('category', ['text_as_category'])  :  2 | ['piezo_station_pe_label', 'piezo_producer_name']
# (_dystack pid=11442) 		('float', [])                       : 54 | ['piezo_station_investigation_depth', 'piezo_station_altitude', 'piezo_station_longitude', 'piezo_station_latitude', 'piezo_producer_code', ...]
# (_dystack pid=11442) 		('int', [])                         :  7 | ['meteo_id', 'meteo_altitude', 'hydro_status_code', 'hydro_qualification_code', 'year', ...]
# (_dystack pid=11442) 		('int', ['binned', 'text_special']) : 20 | ['piezo_station_pe_label.char_count', 'piezo_station_pe_label.word_count', 'piezo_station_pe_label.capital_ratio', 'piezo_station_pe_label.lower_ratio', 'piezo_station_pe_label.digit_ratio', ...]
# (_dystack pid=11442) 		('int', ['bool'])                   :  2 | ['piezo_continuity_code', 'hydro_hydro_quantity_elab']
# (_dystack pid=11442) 		('int', ['text_ngram'])             : 67 | ['__nlp__.1219', '__nlp__.196', '__nlp__.197', '__nlp__.198', '__nlp__.22400001800016', ...]
# (_dystack pid=11442) 	217.8s = Fit runtime
# (_dystack pid=11442) 	87 features in original data used to generate 174 features in processed data.
# (_dystack pid=11442) 	Train Data (Processed) Memory Usage: 1278.35 MB (2.0% of available memory)
# (_dystack pid=11442) Data preprocessing and feature engineering runtime = 226.77s ...
# (_dystack pid=11442) AutoGluon will gauge predictive performance using evaluation metric: 'f1_weighted'
# (_dystack pid=11442) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=11442) User-specified model hyperparameters to be fit:
# (_dystack pid=11442) {
# (_dystack pid=11442) 	'CAT': [{'iterations': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# (_dystack pid=11442) 	'GBM': [{'n_estimators': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# (_dystack pid=11442) 	'XGB': [{'n_estimators': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# (_dystack pid=11442) 	'FASTAI': [{}],
# (_dystack pid=11442) }
# (_dystack pid=11442) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=11442) Fitting 4 L1 models, fit_strategy="sequential" ...
# (_dystack pid=11442) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1648.40s of the 2473.22s of remaining time.
# (_dystack pid=11442) 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 23.70% memory usage per fold, 47.41%/80.00% total).
# (_dystack pid=11442) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=23.70%)
# (_ray_fit pid=13320) 	Ran out of time, stopping training early. (Stopping on epoch 1)
# (_ray_fit pid=14868) 	Ran out of time, stopping training early. (Stopping on epoch 0) [repeated 2x across cluster]
# (_ray_fit pid=14751) 	Ran out of time, early stopping on iteration 15.
# (_ray_fit pid=14752) 	Ran out of time, early stopping on iteration 15.
# (_ray_fit pid=15905) 	Ran out of time, stopping training early. (Stopping on epoch 0)
# (_ray_fit pid=16393) 	Ran out of time, early stopping on iteration 15.
# (_ray_fit pid=17077) 	Ran out of time, stopping training early. (Stopping on epoch 0)
# (_ray_fit pid=16504) 	Ran out of time, early stopping on iteration 15.
# (_ray_fit pid=18249) 	Ran out of time, stopping training early. (Stopping on epoch 0)
# (_ray_fit pid=18045) 	Ran out of time, early stopping on iteration 15.
# (_ray_fit pid=18139) 	Ran out of time, early stopping on iteration 15.
# (_ray_fit pid=19304) 	Ran out of time, stopping training early. (Stopping on epoch 0)
# (_ray_fit pid=19758) 	Ran out of time, early stopping on iteration 14.
# (_ray_fit pid=19860) 	Ran out of time, early stopping on iteration 15.
# (_dystack pid=4621) 	0.5134	 = Validation score   (f1_weighted)
# (_dystack pid=4621) 	1230.69s	 = Training   runtime
# (_dystack pid=4621) 	1.69s	 = Validation runtime
# (_dystack pid=4621) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the -109.78s of remaining time.
# (_ray_fit pid=20464) 	Ran out of time, stopping training early. (Stopping on epoch 0)
# (_dystack pid=11442) 	0.84	 = Validation score   (f1_weighted)
# (_dystack pid=11442) 	1524.17s	 = Training   runtime
# (_dystack pid=11442) 	51.69s	 = Validation runtime
# (_dystack pid=11442) Fitting model: LightGBM_BAG_L1 ... Training model for up to 112.10s of the 936.92s of remaining time.
# (_dystack pid=11442) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.08% memory usage per fold, 64.31%/80.00% total).
# (_dystack pid=11442) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=16.08%)
# (_dystack pid=4621) 	Ensemble Weights: {'LightGBM_BAG_L1': 1.0}
# (_dystack pid=4621) 	0.7592	 = Validation score   (f1_weighted)
# (_dystack pid=4621) 	20.8s	 = Training   runtime
# (_dystack pid=4621) 	0.75s	 = Validation runtime
# (_dystack pid=4621) Fitting 4 L2 models, fit_strategy="sequential" ...
# (_dystack pid=4621) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -132.40s of remaining time.
# (_dystack pid=4621) 	Ensemble Weights: {'LightGBM_BAG_L1': 1.0}
# (_dystack pid=4621) 	0.7592	 = Validation score   (f1_weighted)
# (_dystack pid=4621) 	20.08s	 = Training   runtime
# (_dystack pid=4621) 	0.73s	 = Validation runtime
# (_dystack pid=4621) AutoGluon training complete, total runtime = 2851.9s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 2936.7 rows/s (251584 batch size)
# (_dystack pid=4621) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20241201_095214/ds_sub_fit/sub_fit_ho")
# (_dystack pid=4621) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=4621) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_dystack pid=4621) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_dystack pid=4621)
# (_dystack pid=4621) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_dystack pid=4621) This will raise in a future version.
# (_dystack pid=4621)
# (_dystack pid=4621)   warnings.warn(msg, FutureWarning)
# (_dystack pid=4621) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# (_ray_fit pid=22253) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=22253) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=22253)
# (_ray_fit pid=22253) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=22253) This will raise in a future version.
# (_ray_fit pid=22253)
# (_ray_fit pid=22253)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=22250)
# (_ray_fit pid=22250)
# (_ray_fit pid=22253) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=22253)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=22252)
# (_ray_fit pid=22252)
# (_ray_fit pid=22251)
# (_ray_fit pid=22251)
# (_ray_fit pid=22251) 	Ran out of time, early stopping on iteration 8. Best iteration is:
# (_ray_fit pid=22251) 	[8]	valid_set's multi_logloss: 1.21576	valid_set's f1_weighted: 0.593972
# (_ray_fit pid=22251) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 3x across cluster]
# (_ray_fit pid=22251) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 3x across cluster]
# (_ray_fit pid=22251) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 3x across cluster]
# (_ray_fit pid=22251) This will raise in a future version. [repeated 3x across cluster]
# (_ray_fit pid=22251)   warnings.warn(msg, FutureWarning) [repeated 3x across cluster]
# (_ray_fit pid=22251) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument [repeated 3x across cluster]
# (_ray_fit pid=22251)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument") [repeated 3x across cluster]
# (_ray_fit pid=22698)
# (_ray_fit pid=22698)
# (_ray_fit pid=22253) 	Ran out of time, early stopping on iteration 8. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=22253) 	[8]	valid_set's multi_logloss: 1.21621	valid_set's f1_weighted: 0.589978 [repeated 3x across cluster]
# (_ray_fit pid=22698) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=22698) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=22698) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=22698) This will raise in a future version.
# (_ray_fit pid=22698)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=22701) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=22701) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=22701)
# (_ray_fit pid=22701) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=22701) This will raise in a future version.
# (_ray_fit pid=22701)
# (_ray_fit pid=22701)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=22700)
# (_ray_fit pid=22700)
# (_ray_fit pid=22698) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=22698)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=22698) 	Ran out of time, early stopping on iteration 10. Best iteration is:
# (_ray_fit pid=22698) 	[10]	valid_set's multi_logloss: 1.17085	valid_set's f1_weighted: 0.600911
# (_ray_fit pid=22700) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=22700) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=22700) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=22700) This will raise in a future version.
# (_ray_fit pid=22700)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=22700) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument [repeated 2x across cluster]
# (_ray_fit pid=22700)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument") [repeated 2x across cluster]
# (_ray_fit pid=22701) 	Ran out of time, early stopping on iteration 10. Best iteration is:
# (_ray_fit pid=22701) 	[10]	valid_set's multi_logloss: 1.17155	valid_set's f1_weighted: 0.603703
# (_ray_fit pid=23091) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=23091) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=23091)
# (_ray_fit pid=23091) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=23091) This will raise in a future version.
# (_ray_fit pid=23091)
# (_ray_fit pid=23091)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=22700) 	Ran out of time, early stopping on iteration 11. Best iteration is:
# (_ray_fit pid=22700) 	[11]	valid_set's multi_logloss: 1.15191	valid_set's f1_weighted: 0.605521
# (_ray_fit pid=23091) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=23091)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=23091) 	Ran out of time, early stopping on iteration 18. Best iteration is:
# (_ray_fit pid=23091) 	[18]	valid_set's multi_logloss: 1.04451	valid_set's f1_weighted: 0.637073
# (_dystack pid=11442) 	0.6012	 = Validation score   (f1_weighted)
# (_dystack pid=11442) 	141.46s	 = Training   runtime
# (_dystack pid=11442) 	8.48s	 = Validation runtime
# (_dystack pid=11442) Fitting model: WeightedEnsemble_L2 ... Training model for up to 360.00s of the 707.99s of remaining time.
# (_dystack pid=23364) Running DyStack sub-fit ...
# (_dystack pid=23364) Beginning AutoGluon training ... Time limit = 2700s
# (_dystack pid=23364) AutoGluon will save models to "/content/AutogluonModels/ag-20241201_095700/ds_sub_fit/sub_fit_ho"
# (_dystack pid=23364) Train Data Rows:    2012669
# (_dystack pid=23364) Train Data Columns: 94
# (_dystack pid=23364) Label Column:       piezo_groundwater_level_category
# (_dystack pid=23364) Problem Type:       multiclass
# (_dystack pid=23364) Preprocessing data ...
# (_dystack pid=11442) 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 1.0}
# (_dystack pid=11442) 	0.84	 = Validation score   (f1_weighted)
# (_dystack pid=11442) 	19.52s	 = Training   runtime
# (_dystack pid=11442) 	0.73s	 = Validation runtime
# (_dystack pid=11442) Fitting 4 L2 models, fit_strategy="sequential" ...
# (_dystack pid=23364) Train Data Class Count: 5
# (_dystack pid=23364) Using Feature Generators to preprocess the data ...
# (_dystack pid=23364) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=11442) Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 687.54s of the 686.77s of remaining time.
# (_dystack pid=23364) 	Available Memory:                    62495.52 MB
# (_dystack pid=23364) 	Train Data (Original)  Memory Usage: 5418.60 MB (8.7% of available memory)
# (_dystack pid=23364) 	Warning: Data size prior to feature transformation consumes 8.7% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# (_dystack pid=23364) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=11442) 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 26.69% memory usage per fold, 53.37%/80.00% total).
# (_dystack pid=11442) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=26.69%)
# (_dystack pid=23364) 	Stage 1 Generators:
# (_dystack pid=23364) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=23364) 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=23364) 	Stage 2 Generators:
# (_dystack pid=23364) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=23364) 	Stage 3 Generators:
# (_dystack pid=23364) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=23364) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=23364) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=23364) 		Fitting TextSpecialFeatureGenerator...
# (_dystack pid=23364) 			Fitting BinnedFeatureGenerator...
# (_dystack pid=23364) 			Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=23364) 		Fitting TextNgramFeatureGenerator...
# (_dystack pid=23364) 			Fitting CountVectorizer for text features: ['piezo_station_pe_label', 'piezo_producer_name']
# (_dystack pid=23364) 			CountVectorizer fit with vocabulary size = 313
# (_dystack pid=23364) 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# (_dystack pid=23364) 		Reducing Vectorizer vocab size from 313 to 177 to avoid OOM error
# (_dystack pid=23364) 	Stage 4 Generators:
# (_dystack pid=23364) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=23364) 	Stage 5 Generators:
# (_dystack pid=23364) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=23364) 	Useless Original Features (Count: 2): ['hydro_method_code', 'hydro_method_label']
# (_dystack pid=23364) 		These features carry no predictive signal and should be manually investigated.
# (_dystack pid=23364) 		This is typically a feature which has the same value for all rows.
# (_dystack pid=23364) 		These features do not need to be present at inference time.
# (_dystack pid=23364) 	Unused Original Features (Count: 5): ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name']
# (_dystack pid=23364) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=23364) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=23364) 		These features do not need to be present at inference time.
# (_dystack pid=23364) 		('object', []) : 5 | ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name']
# (_dystack pid=23364) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=23364) 		('float', [])        : 55 | ['piezo_station_investigation_depth', 'piezo_station_altitude', 'piezo_station_longitude', 'piezo_station_latitude', 'piezo_continuity_code', ...]
# (_dystack pid=23364) 		('int', [])          :  7 | ['meteo_id', 'meteo_altitude', 'hydro_status_code', 'hydro_qualification_code', 'year', ...]
# (_dystack pid=23364) 		('object', [])       : 23 | ['piezo_station_department_code', 'piezo_station_commune_code_insee', 'piezo_station_bdlisa_codes', 'piezo_station_bss_code', 'piezo_station_commune_name', ...]
# (_dystack pid=23364) 		('object', ['text']) :  2 | ['piezo_station_pe_label', 'piezo_producer_name']
# (_dystack pid=23364) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=23364) 		('category', [])                    : 22 | ['piezo_station_department_code', 'piezo_station_commune_code_insee', 'piezo_station_bdlisa_codes', 'piezo_station_bss_code', 'piezo_station_commune_name', ...]
# (_dystack pid=23364) 		('category', ['text_as_category'])  :  2 | ['piezo_station_pe_label', 'piezo_producer_name']
# (_dystack pid=23364) 		('float', [])                       : 54 | ['piezo_station_investigation_depth', 'piezo_station_altitude', 'piezo_station_longitude', 'piezo_station_latitude', 'piezo_producer_code', ...]
# (_dystack pid=23364) 		('int', [])                         :  7 | ['meteo_id', 'meteo_altitude', 'hydro_status_code', 'hydro_qualification_code', 'year', ...]
# (_dystack pid=23364) 		('int', ['binned', 'text_special']) : 20 | ['piezo_station_pe_label.char_count', 'piezo_station_pe_label.word_count', 'piezo_station_pe_label.capital_ratio', 'piezo_station_pe_label.lower_ratio', 'piezo_station_pe_label.digit_ratio', ...]
# (_dystack pid=23364) 		('int', ['bool'])                   :  2 | ['piezo_continuity_code', 'hydro_hydro_quantity_elab']
# (_dystack pid=23364) 		('int', ['text_ngram'])             : 66 | ['__nlp__.1219', '__nlp__.196', '__nlp__.197', '__nlp__.198', '__nlp__.22400001800016', ...]
# (_dystack pid=23364) 	215.7s = Fit runtime
# (_dystack pid=23364) 	87 features in original data used to generate 173 features in processed data.
# (_dystack pid=23364) 	Train Data (Processed) Memory Usage: 1274.51 MB (2.0% of available memory)
# (_dystack pid=23364) Data preprocessing and feature engineering runtime = 224.86s ...
# (_dystack pid=23364) AutoGluon will gauge predictive performance using evaluation metric: 'f1_weighted'
# (_dystack pid=23364) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=23364) User-specified model hyperparameters to be fit:
# (_dystack pid=23364) {
# (_dystack pid=23364) 	'CAT': [{'iterations': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# (_dystack pid=23364) 	'GBM': [{'n_estimators': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# (_dystack pid=23364) 	'XGB': [{'n_estimators': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# (_dystack pid=23364) 	'FASTAI': [{}],
# (_dystack pid=23364) }
# (_dystack pid=23364) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=23364) Fitting 4 L1 models, fit_strategy="sequential" ...
# (_dystack pid=23364) Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 1649.68s of the 2475.13s of remaining time.
# (_dystack pid=23364) 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 24.68% memory usage per fold, 49.36%/80.00% total).
# (_dystack pid=23364) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=24.68%)
# (_dystack pid=11442) 	Time limit exceeded... Skipping NeuralNetFastAI_BAG_L2.
# (_dystack pid=11442) Fitting model: LightGBM_BAG_L2 ... Training model for up to 437.17s of the 436.40s of remaining time.
# (_dystack pid=11442) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.37% memory usage per fold, 69.46%/80.00% total).
# (_dystack pid=11442) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.37%)
# (_ray_fit pid=25798) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=25798) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=25798)
# (_ray_fit pid=25798) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=25798) This will raise in a future version.
# (_ray_fit pid=25798)
# (_ray_fit pid=25798)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=25799)
# (_ray_fit pid=25799)
# (_ray_fit pid=25797)
# (_ray_fit pid=25797)
# (_ray_fit pid=25800)
# (_ray_fit pid=25800)
# (_ray_fit pid=25798) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=25798)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=25799) 	Ran out of time, early stopping on iteration 47. Best iteration is:
# (_ray_fit pid=25799) 	[47]	valid_set's multi_logloss: 0.377062	valid_set's f1_weighted: 0.847504
# (_ray_fit pid=25800) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:  [repeated 3x across cluster]
# (_ray_fit pid=25800) Dask dataframe query planning is disabled because dask-expr is not installed. [repeated 3x across cluster]
# (_ray_fit pid=25800) You can install it with `pip install dask[dataframe]` or `conda install dask`. [repeated 3x across cluster]
# (_ray_fit pid=25800) This will raise in a future version. [repeated 3x across cluster]
# (_ray_fit pid=25800)   warnings.warn(msg, FutureWarning) [repeated 3x across cluster]
# (_ray_fit pid=25800) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument [repeated 3x across cluster]
# (_ray_fit pid=25800)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument") [repeated 3x across cluster]
# (_ray_fit pid=26814)
# (_ray_fit pid=26814)
# (_ray_fit pid=25798) 	Ran out of time, early stopping on iteration 52. Best iteration is: [repeated 3x across cluster]
# (_ray_fit pid=25798) 	[52]	valid_set's multi_logloss: 0.377515	valid_set's f1_weighted: 0.846039 [repeated 3x across cluster]
# (_ray_fit pid=26814) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=26814) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=26814) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=26814) This will raise in a future version.
# (_ray_fit pid=26814)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=26814) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=26814)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=26829) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=26829) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=26829)
# (_ray_fit pid=26829) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=26829) This will raise in a future version.
# (_ray_fit pid=26829)
# (_ray_fit pid=26829)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=26814) 	Ran out of time, early stopping on iteration 58. Best iteration is:
# (_ray_fit pid=26814) 	[58]	valid_set's multi_logloss: 0.37453	valid_set's f1_weighted: 0.847203
# (_ray_fit pid=26829) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=26829)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=26829) 	Ran out of time, early stopping on iteration 58. Best iteration is:
# (_ray_fit pid=26829) 	[58]	valid_set's multi_logloss: 0.372019	valid_set's f1_weighted: 0.847162
# (_ray_fit pid=27805) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=27805) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=27805)
# (_ray_fit pid=27805) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=27805) This will raise in a future version.
# (_ray_fit pid=27805)
# (_ray_fit pid=27805)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=27805) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=27805)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=27862)
# (_ray_fit pid=27862)
# (_ray_fit pid=26807) 	Ran out of time, stopping training early. (Stopping on epoch 1)
# (_ray_fit pid=27862) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_ray_fit pid=27862) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_ray_fit pid=27862) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_ray_fit pid=27862) This will raise in a future version.
# (_ray_fit pid=27862)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=27862) /usr/local/lib/python3.10/dist-packages/lightgbm/engine.py:204: UserWarning: Found `n_estimators` in params. Will use it instead of argument
# (_ray_fit pid=27862)   _log_warning(f"Found `{alias}` in params. Will use it instead of argument")
# (_ray_fit pid=27805) 	Ran out of time, early stopping on iteration 58. Best iteration is:
# (_ray_fit pid=27805) 	[58]	valid_set's multi_logloss: 0.37314	valid_set's f1_weighted: 0.84754
# (_dystack pid=11442) 	0.847	 = Validation score   (f1_weighted)
# (_dystack pid=11442) 	537.6s	 = Training   runtime
# (_dystack pid=11442) 	22.12s	 = Validation runtime
# (_ray_fit pid=27862) 	Ran out of time, early stopping on iteration 60. Best iteration is:
# (_ray_fit pid=27862) 	[59]	valid_set's multi_logloss: 0.372132	valid_set's f1_weighted: 0.84788
# (_dystack pid=11442) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -117.52s of remaining time.
# (_dystack pid=11442) 	Ensemble Weights: {'LightGBM_BAG_L2': 0.96, 'LightGBM_BAG_L1': 0.04}
# (_dystack pid=11442) 	0.847	 = Validation score   (f1_weighted)
# (_dystack pid=11442) 	34.6s	 = Training   runtime
# (_dystack pid=11442) 	0.96s	 = Validation runtime
# (_dystack pid=11442) AutoGluon training complete, total runtime = 2855.64s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 3052.9 rows/s (251584 batch size)
# (_dystack pid=11442) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20241201_100925/ds_sub_fit/sub_fit_ho")
# (_dystack pid=11442) Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# (_dystack pid=11442) /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# (_dystack pid=11442) Dask dataframe query planning is disabled because dask-expr is not installed.
# (_dystack pid=11442)
# (_dystack pid=11442) You can install it with `pip install dask[dataframe]` or `conda install dask`.
# (_dystack pid=11442) This will raise in a future version.
# (_dystack pid=11442)
# (_dystack pid=11442)   warnings.warn(msg, FutureWarning)
# (_ray_fit pid=28468) 	Ran out of time, stopping training early. (Stopping on epoch 0)
# (_dystack pid=11442) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                     model  score_holdout  score_val  eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBM_BAG_L2       0.872339   0.847023  f1_weighted      357.962180      82.288905  2203.228338                15.530157               22.122514         537.599563            2       True          4
# 1     WeightedEnsemble_L3       0.872173   0.847016  f1_weighted      357.985848      83.252041  2237.827518                 0.023668                0.963136          34.599180            3       True          5
# 2  NeuralNetFastAI_BAG_L1       0.862254   0.839955  f1_weighted      332.361456      51.686005  1524.167932               332.361456               51.686005        1524.167932            1       True          1
# 3     WeightedEnsemble_L2       0.862254   0.839955  f1_weighted      332.371866      52.415594  1543.688541                 0.010409                0.729589          19.520610            2       True          3
# 4         LightGBM_BAG_L1       0.606814   0.601167  f1_weighted       10.070567       8.480387   141.460844                10.070567                8.480387         141.460844            1       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	3292s	 = DyStack   runtime |	7508s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 7508s
# AutoGluon will save models to "/content/AutogluonModels/ag-20241201_100925"
# Train Data Rows:    2264253
# Train Data Columns: 94
# Label Column:       piezo_groundwater_level_category
# Problem Type:       multiclass
# Preprocessing data ...
# Train Data Class Count: 5
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    59806.43 MB
# 	Train Data (Original)  Memory Usage: 6546.64 MB (10.9% of available memory)
# 	Warning: Data size prior to feature transformation consumes 10.9% of available memory. Consider increasing memory or subsampling the data to avoid instability.
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 3 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting TextSpecialFeatureGenerator...
# 			Fitting BinnedFeatureGenerator...
# 			Fitting DropDuplicatesFeatureGenerator...
# 		Fitting TextNgramFeatureGenerator...
# 			Fitting CountVectorizer for text features: ['piezo_station_pe_label', 'piezo_producer_name']
# 			CountVectorizer fit with vocabulary size = 313
# 		Warning: Due to memory constraints, ngram feature count is being reduced. Allocate more memory to maximize model quality.
# 		Reducing Vectorizer vocab size from 313 to 91 to avoid OOM error
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Useless Original Features (Count: 2): ['hydro_method_code', 'hydro_method_label']
# 		These features carry no predictive signal and should be manually investigated.
# 		This is typically a feature which has the same value for all rows.
# 		These features do not need to be present at inference time.
# 	Unused Original Features (Count: 5): ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 5 | ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])        : 55 | ['piezo_station_investigation_depth', 'piezo_station_altitude', 'piezo_station_longitude', 'piezo_station_latitude', 'piezo_continuity_code', ...]
# 		('int', [])          :  7 | ['meteo_id', 'meteo_altitude', 'hydro_status_code', 'hydro_qualification_code', 'year', ...]
# 		('object', [])       : 23 | ['piezo_station_department_code', 'piezo_station_commune_code_insee', 'piezo_station_bdlisa_codes', 'piezo_station_bss_code', 'piezo_station_commune_name', ...]
# 		('object', ['text']) :  2 | ['piezo_station_pe_label', 'piezo_producer_name']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])                    : 22 | ['piezo_station_department_code', 'piezo_station_commune_code_insee', 'piezo_station_bdlisa_codes', 'piezo_station_bss_code', 'piezo_station_commune_name', ...]
# 		('category', ['text_as_category'])  :  2 | ['piezo_station_pe_label', 'piezo_producer_name']
# 		('float', [])                       : 54 | ['piezo_station_investigation_depth', 'piezo_station_altitude', 'piezo_station_longitude', 'piezo_station_latitude', 'piezo_producer_code', ...]
# 		('int', [])                         :  7 | ['meteo_id', 'meteo_altitude', 'hydro_status_code', 'hydro_qualification_code', 'year', ...]
# 		('int', ['binned', 'text_special']) : 19 | ['piezo_station_pe_label.char_count', 'piezo_station_pe_label.word_count', 'piezo_station_pe_label.capital_ratio', 'piezo_station_pe_label.lower_ratio', 'piezo_station_pe_label.digit_ratio', ...]
# 		('int', ['bool'])                   :  2 | ['piezo_continuity_code', 'hydro_hydro_quantity_elab']
# 		('int', ['text_ngram'])             : 40 | ['__nlp__.1219', '__nlp__.196', '__nlp__.265', '__nlp__.291', '__nlp__.293', ...]
# 	360.4s = Fit runtime
# 	87 features in original data used to generate 146 features in processed data.
# 	Train Data (Processed) Memory Usage: 1319.38 MB (2.3% of available memory)
# Data preprocessing and feature engineering runtime = 372.46s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'f1_weighted'
# 	To change this, specify the eval_metric parameter of Predictor()
# User-specified model hyperparameters to be fit:
# {
# 	'CAT': [{'iterations': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# 	'GBM': [{'n_estimators': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# 	'XGB': [{'n_estimators': 100, 'early_stopping_rounds': 20, 'learning_rate': 0.1}],
# 	'FASTAI': [{}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 4 L1 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 4756.08s of the 7135.90s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 28.83% memory usage per fold, 57.66%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=28.83%)
# 	0.8904	 = Validation score   (f1_weighted)
# 	3265.74s	 = Training   runtime
# 	49.51s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 1306.80s of the 3686.63s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.88% memory usage per fold, 59.52%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=14.88%)
# 	0.7595	 = Validation score   (f1_weighted)
# 	648.09s	 = Training   runtime
# 	105.28s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 639.09s of the 3018.91s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 14.93% memory usage per fold, 59.70%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=14.93%)
# 	0.5037	 = Validation score   (f1_weighted)
# 	440.09s	 = Training   runtime
# 	1.86s	 = Validation runtime
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 189.05s of the 2568.87s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.00% memory usage per fold, 76.01%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=19.00%)
# 	0.3471	 = Validation score   (f1_weighted)
# 	685.09s	 = Training   runtime
# 	31.19s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 475.61s of the 1869.82s of remaining time.
# 	Ensemble Weights: {'NeuralNetFastAI_BAG_L1': 0.778, 'LightGBM_BAG_L1': 0.111, 'XGBoost_BAG_L1': 0.111}
# 	0.8906	 = Validation score   (f1_weighted)
# 	41.09s	 = Training   runtime
# 	0.8s	 = Validation runtime
# Fitting 4 L2 models, fit_strategy="sequential" ...
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 1827.51s of the 1826.30s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 25.95% memory usage per fold, 51.91%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=6, gpus=0, memory=25.95%)
# 	0.8914	 = Validation score   (f1_weighted)
# 	1171.69s	 = Training   runtime
# 	51.3s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 636.61s of the 635.39s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.17% memory usage per fold, 68.68%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.17%)
# 	0.8935	 = Validation score   (f1_weighted)
# 	515.36s	 = Training   runtime
# 	30.37s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 103.11s of the 101.90s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.22% memory usage per fold, 68.87%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (4 workers, per: cpus=3, gpus=0, memory=17.22%)
# 	0.8867	 = Validation score   (f1_weighted)
# 	92.64s	 = Training   runtime
# 	1.83s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.00s of the -7.00s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L2': 0.538, 'XGBoost_BAG_L1': 0.308, 'LightGBM_BAG_L1': 0.077, 'CatBoost_BAG_L2': 0.077}
# 	0.8936	 = Validation score   (f1_weighted)
# 	69.06s	 = Training   runtime
# 	0.81s	 = Validation runtime
# AutoGluon training complete, total runtime = 7588.96s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 1285.7 rows/s (283032 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20241201_100925")

# %%
predictor.leaderboard(data=validation_df,extra_metrics=['f1_weighted','precision_weighted','recall_weighted'])
# Out:
# /usr/local/lib/python3.10/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)
#                     model  score_test  f1_weighted  precision_weighted  \
# 0         LightGBM_BAG_L2    0.909365     0.909365            0.909504
# 1     WeightedEnsemble_L3    0.908798     0.908798            0.908947
# 2  NeuralNetFastAI_BAG_L2    0.904928     0.904928            0.905125
# 3  NeuralNetFastAI_BAG_L1    0.903243     0.903243            0.903351
# 4     WeightedEnsemble_L2    0.902696     0.902696            0.902806
# 5         CatBoost_BAG_L2    0.900801     0.900801            0.901891
# 6         LightGBM_BAG_L1    0.761017     0.761017            0.761627
# 7         CatBoost_BAG_L1    0.504602     0.504602            0.514647
# 8          XGBoost_BAG_L1    0.354566     0.354566            0.360113
#
#    recall_weighted  score_val  eval_metric  pred_time_test  pred_time_val  \
# 0         0.909272   0.893485  f1_weighted      247.544981     218.208316
# 1         0.908699   0.893640  f1_weighted      249.895154     220.851622
# 2         0.904804   0.891360  f1_weighted      297.428190     239.140563
# 3         0.903173   0.890431  f1_weighted       74.078047      49.505973
# 4         0.902627   0.890626  f1_weighted      221.776691     186.777494
# 5         0.900548   0.886651  f1_weighted      226.023289     189.674624
# 6         0.761493   0.759515  f1_weighted       83.643595     105.279311
# 7         0.502902   0.503686  f1_weighted        2.051291       1.864392
# 8         0.355598   0.347141  f1_weighted       63.995963      31.192045
#
#       fit_time  pred_time_test_marginal  pred_time_val_marginal  \
# 0  5554.367122                23.776085               30.366595
# 1  5716.071968                 0.095779                0.810403
# 2  6210.697756                73.659294               51.298842
# 3  3265.742370                74.078047               49.505973
# 4  4640.009723                 0.059086                0.800165
# 5  5131.653439                 2.254394                1.832903
# 6   648.088736                83.643595              105.279311
# 7   440.090556                 2.051291                1.864392
# 8   685.089911                63.995963               31.192045
#
#    fit_time_marginal  stack_level  can_infer  fit_order
# 0         515.355550            2       True          7
# 1          69.062979            3       True          9
# 2        1171.686183            2       True          6
# 3        3265.742370            1       True          1
# 4          41.088707            2       True          5
# 5          92.641867            2       True          8
# 6         648.088736            1       True          2
# 7         440.090556            1       True          3
# 8         685.089911            1       True          4

# %%
predictor.feature_importance(train_df)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['piezo_station_department_name', 'piezo_station_bss_id', 'piezo_bss_code', 'piezo_continuity_name', 'piezo_measure_nature_name', 'hydro_method_code', 'hydro_method_label']
# Computing feature importance via permutation shuffling for 87 features using 5000 rows with 5 shuffle sets...
# 	2413.69s	= Expected runtime (482.74s per shuffle set)
# 	1060.84s	= Actual runtime (Completed 5 of 5 shuffle sets)
#                          importance    stddev       p_value  n  p99_high  \
# piezo_station_bss_code     0.412016  0.010692  5.436743e-08  5  0.434030
# month                      0.407270  0.008556  2.336284e-08  5  0.424887
# year                       0.309584  0.007381  3.874980e-08  5  0.324782
# temp_avg_14d               0.070096  0.004046  1.326201e-06  5  0.078427
# rain_sum_14d               0.053010  0.002931  1.116272e-06  5  0.059045
# ...                             ...       ...           ... ..       ...
# meteo_temperature_min     -0.000159  0.001248  6.049724e-01  5  0.002410
# meteo_latitude            -0.000203  0.000768  7.069120e-01  5  0.001378
# meteo_temperature_avg     -0.000240  0.000671  7.659617e-01  5  0.001141
# insee_%_const             -0.000241  0.000171  9.829692e-01  5  0.000110
# meteo_time_humidity_min   -0.000273  0.000389  9.040736e-01  5  0.000528
#
#                           p99_low
# piezo_station_bss_code   0.390001
# month                    0.389652
# year                     0.294386
# temp_avg_14d             0.061766
# rain_sum_14d             0.046976
# ...                           ...
# meteo_temperature_min   -0.002728
# meteo_latitude          -0.001784
# meteo_temperature_avg   -0.001622
# insee_%_const           -0.000592
# meteo_time_humidity_min -0.001073
#
# [87 rows x 6 columns]

# %%
preds = predictor.predict(data=X_test)

id=pd.read_csv('/content/y_test_submission_example_Hi5.csv')
id['piezo_groundwater_level_category'] = preds
id.to_csv('all_data_best_q.csv',index=False)

# %% [markdown]
# # Saving model parameters

# %%
if os.path.exists('/content/AutogluonModels'):
    # !tar -czvf autogluon_models.tar.gz /content/AutogluonModels
else:
    print("Path doesn't exist")
# Out:
# tar: Removing leading `/' from member names
# /content/AutogluonModels/
# /content/AutogluonModels/ag-20241201_095700/
# /content/AutogluonModels/ag-20241201_095700/ds_sub_fit/
# /content/AutogluonModels/ag-20241201_100925/
# /content/AutogluonModels/ag-20241201_100925/version.txt
# /content/AutogluonModels/ag-20241201_100925/learner.pkl
# /content/AutogluonModels/ag-20241201_100925/predictor.pkl
# /content/AutogluonModels/ag-20241201_100925/utils/
# /content/AutogluonModels/ag-20241201_100925/utils/data/
# /content/AutogluonModels/ag-20241201_100925/utils/data/y.pkl
# /content/AutogluonModels/ag-20241201_100925/utils/data/X.pkl
# /content/AutogluonModels/ag-20241201_100925/models/
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L3/
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L3/utils/
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L3/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L3/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F8/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F7/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F5/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/utils/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F4/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F1/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F6/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F2/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L2/S1F3/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F8/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F7/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F5/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/utils/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F4/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F1/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F6/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F2/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F3/xgb.ubj
# /content/AutogluonModels/ag-20241201_100925/models/XGBoost_BAG_L1/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/trainer.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/utils/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L2/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/utils/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L2/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/utils/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/CatBoost_BAG_L1/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/utils/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/LightGBM_BAG_L1/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F8/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F8/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F8/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F7/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F7/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F7/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F5/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F5/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F5/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/utils/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F4/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F4/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F4/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F1/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F1/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F1/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F6/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F6/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F6/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F2/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F2/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F3/
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F3/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/NeuralNetFastAI_BAG_L1/S1F3/model-internals.pkl
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L2/
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L2/model.pkl
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L2/utils/
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L2/utils/oof.pkl
# /content/AutogluonModels/ag-20241201_100925/models/WeightedEnsemble_L2/utils/model_template.pkl
# /content/AutogluonModels/ag-20241201_100925/metadata.json
# /content/AutogluonModels/ag-20241201_095214/
# /content/AutogluonModels/ag-20241201_095214/ds_sub_fit/
# 打包完成！文件保存为：autogluon_models.tar.gz
